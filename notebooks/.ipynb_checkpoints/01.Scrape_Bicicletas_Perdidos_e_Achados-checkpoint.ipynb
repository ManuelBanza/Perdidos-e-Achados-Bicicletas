# %%
import requests
import time
import pandas as pd
from bs4 import BeautifulSoup as bs
from requests.exceptions import ConnectionError
from datetime import datetime
from datetime import date
import itertools

# %%
# Criar lista com os dias
days = pd.date_range(end = pd.datetime.today(), periods=365, freq='D').strftime('%d-%m-%Y').tolist()

# Criar lista para páginas
pages = list(range(1,11))
# Out:
# /tmp/ipykernel_102446/2020583670.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   days = pd.date_range(end = pd.datetime.today(), periods=365, freq='D').strftime('%d-%m-%Y').tolist()

# %%
# %%time

### Página 0

# Criar loop que pesquise cada dia

df = pd.DataFrame()

try:  
    for day in days:
        headers = {
            'Host': 'perdidoseachados.mai.gov.pt',
            'User-Agent': 'Mozilla/5.0 (X11; Fedora; Linux x86_64; rv:97.0) Gecko/20100101 Firefox/97.0',
            'Accept': 'application/xml, text/xml, */*; q=0.01',
            'Accept-Language': 'en-GB,en;q=0.5',
            'Accept-Encoding': 'gzip, deflate, br',
            'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
            'X-Requested-With': 'XMLHttpRequest',
            'Content-Length': '114',
            'Origin': 'https://perdidoseachados.mai.gov.pt',
            'Connection': 'keep-alive',
            'Referer': 'https://perdidoseachados.mai.gov.pt/SIISPA2013/default.aspx',
            'Cookie': 'ASP.NET_SessionId=y0ckpfnetdfng3upp4brvgyf; InfoSG=!vyDw9VeOX/lxLBoCoPu/tYv6QITGdZXrKcGSt6QMhdwBScK5ny/LGmetQNVC8qD5e/moZPlYkudkrg==; TS014826ac=01a7b7ad1014347acf0fe02101804320a7976283532448013620fb046fc184b069b325ea2312b33257a185232689ea0fc730b09b87875e60f93d82d7175e78788f36369a74f09639291ca84166ddd4c3651ee24951; TS8ac0f2f4027=0884e346f6ab2000a920071de937e72c9a99a36f3437a7f3ac15d15df1c51ba2ad0827a8feb80dc10830b12beb113000f499d8d8b927e5f6bc3127fe1f931aa32ca4e88563d5d2e849fc611102c9f093fc768cdca01f7a7ec0a07f2512a64a51; TS01fb1014=01a86827a79ad70709ac28e968d8ae2b3094628295751d2fad587da8a8117e728680a7dcf0bf09e00cfa2d11f95433ffbafcdd8ac4; TS1efd216b027=083771d179ab2000b21e0bdfdd56aef0630f3dd0eb6d3cf1618a30cf62c0365b5639dc2c6840eef608301740fa11300060dac51116233b7924aefe83eb9069f84513fb40f623f91505dab0ebe24978f6ff65340a117f1e06c9a510960d9bff8b',
            'Sec-Fetch-Dest': 'empty',
            'Sec-Fetch-Mode': 'cors',
            'Sec-Fetch-Site': 'same-origin'}

        url = 'https://perdidoseachados.mai.gov.pt/SIISPA2013/search.aspx'
        payload = {
            "txtSearch": "a",
            "date": "{}".format(day),
            "groupId": "1",
            "typeDesc": "OBJECTOS PESSOAIS",
            "subTypeDesc": "BICICLETA",
            "pi": "0",
            "localDesc": "",
            "searchMode": ""
        }

        time.sleep(0.1)
        r = requests.post(url, data=payload, headers=headers)
        result = pd.read_xml(r.content, xpath=".//ROW")
        df = df.append(result)
except:
    pass
# Out:
# CPU times: user 1.31 s, sys: 72.1 ms, total: 1.38 s
# Wall time: 29.1 s

# %%
# %%time

### Página 1

# Criar loop que pesquise cada dia

df_1 = pd.DataFrame()

try:  
    for day in days:
        headers = {
            'Host': 'perdidoseachados.mai.gov.pt',
            'User-Agent': 'Mozilla/5.0 (X11; Fedora; Linux x86_64; rv:97.0) Gecko/20100101 Firefox/97.0',
            'Accept': 'application/xml, text/xml, */*; q=0.01',
            'Accept-Language': 'en-GB,en;q=0.5',
            'Accept-Encoding': 'gzip, deflate, br',
            'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
            'X-Requested-With': 'XMLHttpRequest',
            'Content-Length': '114',
            'Origin': 'https://perdidoseachados.mai.gov.pt',
            'Connection': 'keep-alive',
            'Referer': 'https://perdidoseachados.mai.gov.pt/SIISPA2013/default.aspx',
            'Cookie': 'ASP.NET_SessionId=y0ckpfnetdfng3upp4brvgyf; InfoSG=!vyDw9VeOX/lxLBoCoPu/tYv6QITGdZXrKcGSt6QMhdwBScK5ny/LGmetQNVC8qD5e/moZPlYkudkrg==; TS014826ac=01a7b7ad1014347acf0fe02101804320a7976283532448013620fb046fc184b069b325ea2312b33257a185232689ea0fc730b09b87875e60f93d82d7175e78788f36369a74f09639291ca84166ddd4c3651ee24951; TS8ac0f2f4027=0884e346f6ab2000a920071de937e72c9a99a36f3437a7f3ac15d15df1c51ba2ad0827a8feb80dc10830b12beb113000f499d8d8b927e5f6bc3127fe1f931aa32ca4e88563d5d2e849fc611102c9f093fc768cdca01f7a7ec0a07f2512a64a51; TS01fb1014=01a86827a79ad70709ac28e968d8ae2b3094628295751d2fad587da8a8117e728680a7dcf0bf09e00cfa2d11f95433ffbafcdd8ac4; TS1efd216b027=083771d179ab2000b21e0bdfdd56aef0630f3dd0eb6d3cf1618a30cf62c0365b5639dc2c6840eef608301740fa11300060dac51116233b7924aefe83eb9069f84513fb40f623f91505dab0ebe24978f6ff65340a117f1e06c9a510960d9bff8b',
            'Sec-Fetch-Dest': 'empty',
            'Sec-Fetch-Mode': 'cors',
            'Sec-Fetch-Site': 'same-origin'}

        url = 'https://perdidoseachados.mai.gov.pt/SIISPA2013/search.aspx'
        payload = {
            "txtSearch": "a",
            "date": "{}".format(day),
            "groupId": "1",
            "typeDesc": "OBJECTOS PESSOAIS",
            "subTypeDesc": "BICICLETA",
            "pi": "1",
            "localDesc": "",
            "searchMode": ""
        }

        time.sleep(0.1)
        r = requests.post(url, data=payload, headers=headers)
        result = pd.read_xml(r.content, xpath=".//ROW")
        df_1 = df_1.append(result)
except:
    pass
# Out:
# CPU times: user 5.41 ms, sys: 2.81 ms, total: 8.23 ms
# Wall time: 108 ms

# %%
# %%time

### Página 2

# Criar loop que pesquise cada dia

df_2 = pd.DataFrame()

try:  
    for day in days:
        headers = {
            'Host': 'perdidoseachados.mai.gov.pt',
            'User-Agent': 'Mozilla/5.0 (X11; Fedora; Linux x86_64; rv:97.0) Gecko/20100101 Firefox/97.0',
            'Accept': 'application/xml, text/xml, */*; q=0.01',
            'Accept-Language': 'en-GB,en;q=0.5',
            'Accept-Encoding': 'gzip, deflate, br',
            'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
            'X-Requested-With': 'XMLHttpRequest',
            'Content-Length': '114',
            'Origin': 'https://perdidoseachados.mai.gov.pt',
            'Connection': 'keep-alive',
            'Referer': 'https://perdidoseachados.mai.gov.pt/SIISPA2013/default.aspx',
            'Cookie': 'ASP.NET_SessionId=y0ckpfnetdfng3upp4brvgyf; InfoSG=!vyDw9VeOX/lxLBoCoPu/tYv6QITGdZXrKcGSt6QMhdwBScK5ny/LGmetQNVC8qD5e/moZPlYkudkrg==; TS014826ac=01a7b7ad1014347acf0fe02101804320a7976283532448013620fb046fc184b069b325ea2312b33257a185232689ea0fc730b09b87875e60f93d82d7175e78788f36369a74f09639291ca84166ddd4c3651ee24951; TS8ac0f2f4027=0884e346f6ab2000a920071de937e72c9a99a36f3437a7f3ac15d15df1c51ba2ad0827a8feb80dc10830b12beb113000f499d8d8b927e5f6bc3127fe1f931aa32ca4e88563d5d2e849fc611102c9f093fc768cdca01f7a7ec0a07f2512a64a51; TS01fb1014=01a86827a79ad70709ac28e968d8ae2b3094628295751d2fad587da8a8117e728680a7dcf0bf09e00cfa2d11f95433ffbafcdd8ac4; TS1efd216b027=083771d179ab2000b21e0bdfdd56aef0630f3dd0eb6d3cf1618a30cf62c0365b5639dc2c6840eef608301740fa11300060dac51116233b7924aefe83eb9069f84513fb40f623f91505dab0ebe24978f6ff65340a117f1e06c9a510960d9bff8b',
            'Sec-Fetch-Dest': 'empty',
            'Sec-Fetch-Mode': 'cors',
            'Sec-Fetch-Site': 'same-origin'}

        url = 'https://perdidoseachados.mai.gov.pt/SIISPA2013/search.aspx'
        payload = {
            "txtSearch": "a",
            "date": "{}".format(day),
            "groupId": "1",
            "typeDesc": "OBJECTOS PESSOAIS",
            "subTypeDesc": "BICICLETA",
            "pi": "1",
            "localDesc": "",
            "searchMode": ""
        }

        time.sleep(0.1)
        r = requests.post(url, data=payload, headers=headers)
        result = pd.read_xml(r.content, xpath=".//ROW")
        df_2 = df_2.append(result)
except:
    pass
# Out:
# CPU times: user 5.47 ms, sys: 1.72 ms, total: 7.18 ms
# Wall time: 106 ms

# %%
# %%time

### Página 3

# Criar loop que pesquise cada dia

df_3 = pd.DataFrame()

try:  
    for day in days:
        headers = {
            'Host': 'perdidoseachados.mai.gov.pt',
            'User-Agent': 'Mozilla/5.0 (X11; Fedora; Linux x86_64; rv:97.0) Gecko/20100101 Firefox/97.0',
            'Accept': 'application/xml, text/xml, */*; q=0.01',
            'Accept-Language': 'en-GB,en;q=0.5',
            'Accept-Encoding': 'gzip, deflate, br',
            'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
            'X-Requested-With': 'XMLHttpRequest',
            'Content-Length': '114',
            'Origin': 'https://perdidoseachados.mai.gov.pt',
            'Connection': 'keep-alive',
            'Referer': 'https://perdidoseachados.mai.gov.pt/SIISPA2013/default.aspx',
            'Cookie': 'ASP.NET_SessionId=y0ckpfnetdfng3upp4brvgyf; InfoSG=!vyDw9VeOX/lxLBoCoPu/tYv6QITGdZXrKcGSt6QMhdwBScK5ny/LGmetQNVC8qD5e/moZPlYkudkrg==; TS014826ac=01a7b7ad1014347acf0fe02101804320a7976283532448013620fb046fc184b069b325ea2312b33257a185232689ea0fc730b09b87875e60f93d82d7175e78788f36369a74f09639291ca84166ddd4c3651ee24951; TS8ac0f2f4027=0884e346f6ab2000a920071de937e72c9a99a36f3437a7f3ac15d15df1c51ba2ad0827a8feb80dc10830b12beb113000f499d8d8b927e5f6bc3127fe1f931aa32ca4e88563d5d2e849fc611102c9f093fc768cdca01f7a7ec0a07f2512a64a51; TS01fb1014=01a86827a79ad70709ac28e968d8ae2b3094628295751d2fad587da8a8117e728680a7dcf0bf09e00cfa2d11f95433ffbafcdd8ac4; TS1efd216b027=083771d179ab2000b21e0bdfdd56aef0630f3dd0eb6d3cf1618a30cf62c0365b5639dc2c6840eef608301740fa11300060dac51116233b7924aefe83eb9069f84513fb40f623f91505dab0ebe24978f6ff65340a117f1e06c9a510960d9bff8b',
            'Sec-Fetch-Dest': 'empty',
            'Sec-Fetch-Mode': 'cors',
            'Sec-Fetch-Site': 'same-origin'}

        url = 'https://perdidoseachados.mai.gov.pt/SIISPA2013/search.aspx'
        payload = {
            "txtSearch": "a",
            "date": "{}".format(day),
            "groupId": "1",
            "typeDesc": "OBJECTOS PESSOAIS",
            "subTypeDesc": "BICICLETA",
            "pi": "1",
            "localDesc": "",
            "searchMode": ""
        }

        time.sleep(0.1)
        r = requests.post(url, data=payload, headers=headers)
        result = pd.read_xml(r.content, xpath=".//ROW")
        df_3 = df_3.append(result)
except:
    pass
# Out:
# CPU times: user 7.03 ms, sys: 1.76 ms, total: 8.79 ms
# Wall time: 108 ms

# %%
# %%time

### Página 4

# Criar loop que pesquise cada dia

df_4 = pd.DataFrame()

try:  
    for day in days:
        headers = {
            'Host': 'perdidoseachados.mai.gov.pt',
            'User-Agent': 'Mozilla/5.0 (X11; Fedora; Linux x86_64; rv:97.0) Gecko/20100101 Firefox/97.0',
            'Accept': 'application/xml, text/xml, */*; q=0.01',
            'Accept-Language': 'en-GB,en;q=0.5',
            'Accept-Encoding': 'gzip, deflate, br',
            'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
            'X-Requested-With': 'XMLHttpRequest',
            'Content-Length': '114',
            'Origin': 'https://perdidoseachados.mai.gov.pt',
            'Connection': 'keep-alive',
            'Referer': 'https://perdidoseachados.mai.gov.pt/SIISPA2013/default.aspx',
            'Cookie': 'ASP.NET_SessionId=y0ckpfnetdfng3upp4brvgyf; InfoSG=!vyDw9VeOX/lxLBoCoPu/tYv6QITGdZXrKcGSt6QMhdwBScK5ny/LGmetQNVC8qD5e/moZPlYkudkrg==; TS014826ac=01a7b7ad1014347acf0fe02101804320a7976283532448013620fb046fc184b069b325ea2312b33257a185232689ea0fc730b09b87875e60f93d82d7175e78788f36369a74f09639291ca84166ddd4c3651ee24951; TS8ac0f2f4027=0884e346f6ab2000a920071de937e72c9a99a36f3437a7f3ac15d15df1c51ba2ad0827a8feb80dc10830b12beb113000f499d8d8b927e5f6bc3127fe1f931aa32ca4e88563d5d2e849fc611102c9f093fc768cdca01f7a7ec0a07f2512a64a51; TS01fb1014=01a86827a79ad70709ac28e968d8ae2b3094628295751d2fad587da8a8117e728680a7dcf0bf09e00cfa2d11f95433ffbafcdd8ac4; TS1efd216b027=083771d179ab2000b21e0bdfdd56aef0630f3dd0eb6d3cf1618a30cf62c0365b5639dc2c6840eef608301740fa11300060dac51116233b7924aefe83eb9069f84513fb40f623f91505dab0ebe24978f6ff65340a117f1e06c9a510960d9bff8b',
            'Sec-Fetch-Dest': 'empty',
            'Sec-Fetch-Mode': 'cors',
            'Sec-Fetch-Site': 'same-origin'}

        url = 'https://perdidoseachados.mai.gov.pt/SIISPA2013/search.aspx'
        payload = {
            "txtSearch": "a",
            "date": "{}".format(day),
            "groupId": "1",
            "typeDesc": "OBJECTOS PESSOAIS",
            "subTypeDesc": "BICICLETA",
            "pi": "1",
            "localDesc": "",
            "searchMode": ""
        }

        time.sleep(0.1)
        r = requests.post(url, data=payload, headers=headers)
        result = pd.read_xml(r.content, xpath=".//ROW")
        df_4 = df_4.append(result)
except:
    pass
# Out:
# CPU times: user 5.91 ms, sys: 2.74 ms, total: 8.65 ms
# Wall time: 109 ms

# %%
# %%time

### Página 5

# Criar loop que pesquise cada dia

df_5 = pd.DataFrame()

try:  
    for day in days:
        headers = {
            'Host': 'perdidoseachados.mai.gov.pt',
            'User-Agent': 'Mozilla/5.0 (X11; Fedora; Linux x86_64; rv:97.0) Gecko/20100101 Firefox/97.0',
            'Accept': 'application/xml, text/xml, */*; q=0.01',
            'Accept-Language': 'en-GB,en;q=0.5',
            'Accept-Encoding': 'gzip, deflate, br',
            'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
            'X-Requested-With': 'XMLHttpRequest',
            'Content-Length': '114',
            'Origin': 'https://perdidoseachados.mai.gov.pt',
            'Connection': 'keep-alive',
            'Referer': 'https://perdidoseachados.mai.gov.pt/SIISPA2013/default.aspx',
            'Cookie': 'ASP.NET_SessionId=y0ckpfnetdfng3upp4brvgyf; InfoSG=!vyDw9VeOX/lxLBoCoPu/tYv6QITGdZXrKcGSt6QMhdwBScK5ny/LGmetQNVC8qD5e/moZPlYkudkrg==; TS014826ac=01a7b7ad1014347acf0fe02101804320a7976283532448013620fb046fc184b069b325ea2312b33257a185232689ea0fc730b09b87875e60f93d82d7175e78788f36369a74f09639291ca84166ddd4c3651ee24951; TS8ac0f2f4027=0884e346f6ab2000a920071de937e72c9a99a36f3437a7f3ac15d15df1c51ba2ad0827a8feb80dc10830b12beb113000f499d8d8b927e5f6bc3127fe1f931aa32ca4e88563d5d2e849fc611102c9f093fc768cdca01f7a7ec0a07f2512a64a51; TS01fb1014=01a86827a79ad70709ac28e968d8ae2b3094628295751d2fad587da8a8117e728680a7dcf0bf09e00cfa2d11f95433ffbafcdd8ac4; TS1efd216b027=083771d179ab2000b21e0bdfdd56aef0630f3dd0eb6d3cf1618a30cf62c0365b5639dc2c6840eef608301740fa11300060dac51116233b7924aefe83eb9069f84513fb40f623f91505dab0ebe24978f6ff65340a117f1e06c9a510960d9bff8b',
            'Sec-Fetch-Dest': 'empty',
            'Sec-Fetch-Mode': 'cors',
            'Sec-Fetch-Site': 'same-origin'}

        url = 'https://perdidoseachados.mai.gov.pt/SIISPA2013/search.aspx'
        payload = {
            "txtSearch": "a",
            "date": "{}".format(day),
            "groupId": "1",
            "typeDesc": "OBJECTOS PESSOAIS",
            "subTypeDesc": "BICICLETA",
            "pi": "1",
            "localDesc": "",
            "searchMode": ""
        }

        time.sleep(0.1)
        r = requests.post(url, data=payload, headers=headers)
        result = pd.read_xml(r.content, xpath=".//ROW")
        df_5 = df_5.append(result)
except:
    pass
# Out:
# CPU times: user 5.27 ms, sys: 2.53 ms, total: 7.79 ms
# Wall time: 108 ms

# %%
# %%time

### Página 6

# Criar loop que pesquise cada dia

df_6 = pd.DataFrame()

try:  
    for day in days:
        headers = {
            'Host': 'perdidoseachados.mai.gov.pt',
            'User-Agent': 'Mozilla/5.0 (X11; Fedora; Linux x86_64; rv:97.0) Gecko/20100101 Firefox/97.0',
            'Accept': 'application/xml, text/xml, */*; q=0.01',
            'Accept-Language': 'en-GB,en;q=0.5',
            'Accept-Encoding': 'gzip, deflate, br',
            'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
            'X-Requested-With': 'XMLHttpRequest',
            'Content-Length': '114',
            'Origin': 'https://perdidoseachados.mai.gov.pt',
            'Connection': 'keep-alive',
            'Referer': 'https://perdidoseachados.mai.gov.pt/SIISPA2013/default.aspx',
            'Cookie': 'ASP.NET_SessionId=y0ckpfnetdfng3upp4brvgyf; InfoSG=!vyDw9VeOX/lxLBoCoPu/tYv6QITGdZXrKcGSt6QMhdwBScK5ny/LGmetQNVC8qD5e/moZPlYkudkrg==; TS014826ac=01a7b7ad1014347acf0fe02101804320a7976283532448013620fb046fc184b069b325ea2312b33257a185232689ea0fc730b09b87875e60f93d82d7175e78788f36369a74f09639291ca84166ddd4c3651ee24951; TS8ac0f2f4027=0884e346f6ab2000a920071de937e72c9a99a36f3437a7f3ac15d15df1c51ba2ad0827a8feb80dc10830b12beb113000f499d8d8b927e5f6bc3127fe1f931aa32ca4e88563d5d2e849fc611102c9f093fc768cdca01f7a7ec0a07f2512a64a51; TS01fb1014=01a86827a79ad70709ac28e968d8ae2b3094628295751d2fad587da8a8117e728680a7dcf0bf09e00cfa2d11f95433ffbafcdd8ac4; TS1efd216b027=083771d179ab2000b21e0bdfdd56aef0630f3dd0eb6d3cf1618a30cf62c0365b5639dc2c6840eef608301740fa11300060dac51116233b7924aefe83eb9069f84513fb40f623f91505dab0ebe24978f6ff65340a117f1e06c9a510960d9bff8b',
            'Sec-Fetch-Dest': 'empty',
            'Sec-Fetch-Mode': 'cors',
            'Sec-Fetch-Site': 'same-origin'}

        url = 'https://perdidoseachados.mai.gov.pt/SIISPA2013/search.aspx'
        payload = {
            "txtSearch": "a",
            "date": "{}".format(day),
            "groupId": "1",
            "typeDesc": "OBJECTOS PESSOAIS",
            "subTypeDesc": "BICICLETA",
            "pi": "1",
            "localDesc": "",
            "searchMode": ""
        }

        time.sleep(0.1)
        r = requests.post(url, data=payload, headers=headers)
        result = pd.read_xml(r.content, xpath=".//ROW")
        df_6 = df_6.append(result)
except:
    pass
# Out:
# CPU times: user 4.13 ms, sys: 3.74 ms, total: 7.87 ms
# Wall time: 109 ms

# %% [markdown]
# ### Agregar num dataframe

# %%
df_final = [df, df_1, df_2, df_3, df_4, df_5, df_6]

# %%
df_final.drop_duplicates(subset='NR_REGISTO', keep="first", inplace=True)
print(len(df_final))
print('Existem', df_final.NR_REGISTO.nunique(), 'bicicletas encontradas entre', days[0], 'e', days[-1])
df_final.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_102446/1632035157.py in <module>
# ----> 1 df_final.drop_duplicates(subset='NR_REGISTO', keep="first", inplace=True)
#       2 print(len(df_final))
#       3 print('Existem', df_final.NR_REGISTO.nunique(), 'bicicletas encontradas entre', days[0], 'e', days[-1])
#       4 df_final.head()
#
# AttributeError: 'list' object has no attribute 'drop_duplicates'

# %%
df
# Out:
#     RN  GRUPO               TIPO    SUBTIPO       NR_REGISTO  \
# 0    1      1  OBJECTOS PESSOAIS  BICICLETA  NOBJ00010644/22
# 1    2      1  OBJECTOS PESSOAIS  BICICLETA  NOBJ00008305/22
# 2    3      1  OBJECTOS PESSOAIS  BICICLETA  NOBJ00007904/22
# 3    4      1  OBJECTOS PESSOAIS  BICICLETA  NOBJ00006656/22
# 4    5      1  OBJECTOS PESSOAIS  BICICLETA  NOBJ00006032/22
# ..  ..    ...                ...        ...              ...
# 5    6      1  OBJECTOS PESSOAIS  BICICLETA  NOBJ00005999/22
# 6    7      1  OBJECTOS PESSOAIS  BICICLETA  NOBJ00005670/22
# 7    8      1  OBJECTOS PESSOAIS  BICICLETA  NOBJ00040381/21
# 8    9      1  OBJECTOS PESSOAIS  BICICLETA  NOBJ00038142/21
# 9   10      1  OBJECTOS PESSOAIS  BICICLETA  NOBJ00037848/21
#
#                       DATAREGISTO      PAIS  \
# 0   2022-03-11T08:42:41.777+00:00  PORTUGAL
# 1    2022-02-24T12:24:52.82+00:00  PORTUGAL
# 2   2022-02-22T15:49:32.897+00:00  PORTUGAL
# 3   2022-02-15T14:49:36.207+00:00  PORTUGAL
# 4    2022-02-11T09:19:24.29+00:00  PORTUGAL
# ..                            ...       ...
# 5   2022-02-10T16:56:12.133+00:00  PORTUGAL
# 6    2022-02-09T11:46:07.35+00:00  PORTUGAL
# 7    2021-12-23T09:00:43.44+00:00  PORTUGAL
# 8     2021-12-08T09:44:40.6+00:00  PORTUGAL
# 9   2021-12-06T14:51:47.737+00:00  PORTUGAL
#
#                                            DESCRITIVO  TITULAR  \
# 0   BICICLETA BICICLETA CINZENTA<br><br><strong>Ma...      NaN
# 1   BICICLETA BICICLETA COM QUADRO AZUL, SELIM PRE...      NaN
# 2   BICICLETA BICICLETA MARCA BIKE SPORT, TEAM PRO...      NaN
# 3   BICICLETA<br><br><strong>Marca:</strong> DECAT...      NaN
# 4   BICICLETA BICICLETA AZUL E BRANCA<br><br><stro...      NaN
# ..                                                ...      ...
# 5   BICICLETA<br><br><strong>Marca:</strong> BIKE ...      NaN
# 6   BICICLETA BICICLETA BTT, MARCA QÜER<br><br><st...      NaN
# 7   BICICLETA BICICLETA DE CRIANÇA COR ROSA MARCA ...      NaN
# 8   BICICLETA BICICLETA RODA 20<br><br><strong>Mar...      NaN
# 9   BICICLETA<br><br><strong>Marca:</strong> GT&nb...      NaN
#
#                 MARCA                MODELO  \
# 0              BELCOR                  None
# 1       SHIMANO SIRLA                  None
# 2                None                  None
# 3           DECATHLON  ROCKRIDER BTT ST 100
# 4   TEAM PRO 4210 EMT                  None
# ..                ...                   ...
# 5       BIKE TOUR/EDP                  None
# 6                QÜER                   BTT
# 7                None                  None
# 8                None                  None
# 9                  GT         AVALANCHE 3.0
#
#                                           LOCALIZACAO  \
# 0   <b>EM TRANSFERÊNCIA PARA</b> CUSTÓIAS - MATOSI...
# 1                    CUSTÓIAS - MATOSINHOS - ESQUADRA
# 2   <b>EM TRANSFERÊNCIA PARA</b> GONDOMAR - DIVISÃ...
# 3                            BRAGA - DIVISÃO POLICIAL
# 4                    CUSTÓIAS - MATOSINHOS - ESQUADRA
# ..                                                ...
# 5                            BRAGA - DIVISÃO POLICIAL
# 6                                    LAGOS - ESQUADRA
# 7   <b>EM TRANSFERÊNCIA PARA</b> MATOSINHOS - DIVI...
# 8   <b>EM TRANSFERÊNCIA PARA</b> SANTA MARIA DA FE...
# 9                          CASCAIS - DIVISÃO POLICIAL
#
#                                   LOCALIZACAO_ADDRESS  LOCALIZACAO_LAT  \
# 0     RUA NOVA DE S. GENS, S/N, 4460-781 CUSTÓIAS MTS        41.199564
# 1     RUA NOVA DE S. GENS, S/N, 4460-781 CUSTÓIAS MTS        41.199564
# 2           RUA DA BOAVISTA, S/ N, 4435-123 RIO TINTO        41.175478
# 3           LARGO DE SÃO TIAGO, N.º 6, 4704-504 BRAGA        41.548078
# 4     RUA NOVA DE S. GENS, S/N, 4460-781 CUSTÓIAS MTS        41.199564
# ..                                                ...              ...
# 5           LARGO DE SÃO TIAGO, N.º 6, 4704-504 BRAGA        41.548078
# 6        SÍTIO DA HORTA DO TRIGO, S/N, 8600-324 LAGOS        37.114580
# 7                RUA DE GOA, S/N, 4454-505 MATOSINHOS        41.184541
# 8   RUA DR. PAULO DE SÁ, Nº 2, 4520-219 SANTA MARI...        40.927493
# 9        RUA AFONSO SANCHES, N.º 26, 2750-281 CASCAIS        38.699574
#
#     LOCALIZACAO_LON                                      FullTextValue  \
# 0         -8.644256  OBJECTOS PESSOAIS BICICLETA   BELCOR   PORTUGA...
# 1         -8.644256  OBJECTOS PESSOAIS BICICLETA   SHIMANO SIRLA   ...
# 2         -8.555571  OBJECTOS PESSOAIS BICICLETA      PORTUGAL NOBJ...
# 3         -8.424985  OBJECTOS PESSOAIS BICICLETA   DECATHLON ROCKRI...
# 4         -8.644256  OBJECTOS PESSOAIS BICICLETA   TEAM PRO 4210 EM...
# ..              ...                                                ...
# 5         -8.424985  OBJECTOS PESSOAIS BICICLETA   BIKE TOUR/EDP   ...
# 6         -8.681073  OBJECTOS PESSOAIS BICICLETA   QÜER BTT B1-2516...
# 7         -8.681497  OBJECTOS PESSOAIS BICICLETA      PORTUGAL NOBJ...
# 8         -8.540062  OBJECTOS PESSOAIS BICICLETA      PORTUGAL NOBJ...
# 9         -9.423099  OBJECTOS PESSOAIS BICICLETA   GT AVALANCHE 3.0...
#
#    LOCALIZACAO_DISTRITO                            ACESSIBILITY_DESCRIPTOR
# 0                     -  Registo número NOBJ00010644/22 Registado em: M...
# 1                     -  Registo número NOBJ00008305/22 Registado em: F...
# 2                 PORTO  Registo número NOBJ00007904/22 Registado em: F...
# 3                 BRAGA  Registo número NOBJ00006656/22 Registado em: F...
# 4                     -  Registo número NOBJ00006032/22 Registado em: F...
# ..                  ...                                                ...
# 5                 BRAGA  Registo número NOBJ00005999/22 Registado em: F...
# 6                  FARO  Registo número NOBJ00005670/22 Registado em: F...
# 7                 PORTO  Registo número NOBJ00040381/21 Registado em: D...
# 8                AVEIRO  Registo número NOBJ00038142/21 Registado em: D...
# 9                LISBOA  Registo número NOBJ00037848/21 Registado em: D...
#
# [580 rows x 18 columns]
